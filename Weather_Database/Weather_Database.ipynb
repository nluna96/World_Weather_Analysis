# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

#import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
pip install citipy

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | madison heights
# Processing Record 2 of Set 1 | ahipara
# Processing Record 3 of Set 1 | norman wells
# Processing Record 4 of Set 1 | sinnamary
# Processing Record 5 of Set 1 | caravelas
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | camacari
# Processing Record 8 of Set 1 | ulladulla
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | bristol
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | lubango
# Processing Record 14 of Set 1 | polis
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | kloulklubed
# Processing Record 23 of Set 1 | calobre
# City not found. Skipping...
# Processing Record 24 of Set 1 | vila franca do campo
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | colesberg
# Processing Record 28 of Set 1 | lubu
# Processing Record 29 of Set 1 | victoria
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | gat
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | hasaki
# Processing Record 37 of Set 1 | touros
# Processing Record 38 of Set 1 | sambava
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | deep river
# Processing Record 42 of Set 1 | galesong
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 1 | nizhneivkino
# Processing Record 46 of Set 1 | axim
# Processing Record 47 of Set 1 | cherskiy
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | sao jose da coroa grande
# Processing Record 50 of Set 1 | victoria point
# Processing Record 1 of Set 2 | ilebo
# Processing Record 2 of Set 2 | lompoc
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | chokurdakh
# Processing Record 5 of Set 2 | tuktoyaktuk
# Processing Record 6 of Set 2 | ahuimanu
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 2 | crotone
# Processing Record 10 of Set 2 | souillac
# Processing Record 11 of Set 2 | port-gentil
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | ifakara
# Processing Record 14 of Set 2 | gustavo diaz ordaz
# Processing Record 15 of Set 2 | iqaluit
# Processing Record 16 of Set 2 | aquiraz
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | odweyne
# Processing Record 19 of Set 2 | saldanha
# Processing Record 20 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 2 | saint-philippe
# Processing Record 22 of Set 2 | vredendal
# Processing Record 23 of Set 2 | guerrero negro
# Processing Record 24 of Set 2 | bethel
# Processing Record 25 of Set 2 | tongchuan
# Processing Record 26 of Set 2 | ritchie
# Processing Record 27 of Set 2 | asau
# Processing Record 28 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | kimbe
# Processing Record 31 of Set 2 | atuona
# Processing Record 32 of Set 2 | alpena
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | launceston
# Processing Record 35 of Set 2 | acari
# Processing Record 36 of Set 2 | goderich
# Processing Record 37 of Set 2 | esperance
# Processing Record 38 of Set 2 | pevek
# Processing Record 39 of Set 2 | falciu
# Processing Record 40 of Set 2 | isangel
# Processing Record 41 of Set 2 | bengkulu
# Processing Record 42 of Set 2 | severo-kurilsk
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | hithadhoo
# Processing Record 45 of Set 2 | kahului
# Processing Record 46 of Set 2 | port lincoln
# Processing Record 47 of Set 2 | mango
# Processing Record 48 of Set 2 | codajas
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | bluff
# Processing Record 1 of Set 3 | kuala lipis
# Processing Record 2 of Set 3 | chuy
# Processing Record 3 of Set 3 | jacmel
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | bonavista
# Processing Record 6 of Set 3 | fairbanks
# Processing Record 7 of Set 3 | necochea
# Processing Record 8 of Set 3 | anadyr
# Processing Record 9 of Set 3 | georgetown
# Processing Record 10 of Set 3 | eyl
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | nome
# Processing Record 13 of Set 3 | kruisfontein
# Processing Record 14 of Set 3 | provideniya
# Processing Record 15 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 3 | bodden town
# Processing Record 17 of Set 3 | owando
# Processing Record 18 of Set 3 | sur
# Processing Record 19 of Set 3 | the valley
# Processing Record 20 of Set 3 | kutum
# Processing Record 21 of Set 3 | port moresby
# Processing Record 22 of Set 3 | sobolevo
# Processing Record 23 of Set 3 | atar
# Processing Record 24 of Set 3 | carnarvon
# Processing Record 25 of Set 3 | novyy nekouz
# Processing Record 26 of Set 3 | black river
# Processing Record 27 of Set 3 | namatanai
# Processing Record 28 of Set 3 | kawalu
# Processing Record 29 of Set 3 | rancho palos verdes
# Processing Record 30 of Set 3 | la ronge
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | tazovskiy
# Processing Record 33 of Set 3 | haapsalu
# Processing Record 34 of Set 3 | olafsvik
# Processing Record 35 of Set 3 | haines junction
# Processing Record 36 of Set 3 | east london
# Processing Record 37 of Set 3 | afyonkarahisar
# Processing Record 38 of Set 3 | vao
# Processing Record 39 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 40 of Set 3 | wagar
# Processing Record 41 of Set 3 | svetlogorsk
# Processing Record 42 of Set 3 | cidreira
# Processing Record 43 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 44 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 3 | hay river
# Processing Record 46 of Set 3 | valparaiso
# Processing Record 47 of Set 3 | mantua
# Processing Record 48 of Set 3 | vallenar
# Processing Record 49 of Set 3 | cape town
# Processing Record 50 of Set 3 | vostok
# Processing Record 1 of Set 4 | aswan
# Processing Record 2 of Set 4 | muros
# Processing Record 3 of Set 4 | palu
# Processing Record 4 of Set 4 | linfen
# Processing Record 5 of Set 4 | ponta do sol
# Processing Record 6 of Set 4 | broome
# Processing Record 7 of Set 4 | new norfolk
# Processing Record 8 of Set 4 | pangai
# Processing Record 9 of Set 4 | pergamino
# Processing Record 10 of Set 4 | college
# Processing Record 11 of Set 4 | puerto baquerizo moreno
# Processing Record 12 of Set 4 | ylojarvi
# Processing Record 13 of Set 4 | san quintin
# Processing Record 14 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 4 | bucerias
# Processing Record 16 of Set 4 | aktas
# Processing Record 17 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 18 of Set 4 | ajaccio
# Processing Record 19 of Set 4 | hobart
# Processing Record 20 of Set 4 | bograd
# Processing Record 21 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 4 | esso
# Processing Record 23 of Set 4 | san juan
# Processing Record 24 of Set 4 | nosy varika
# Processing Record 25 of Set 4 | port elizabeth
# Processing Record 26 of Set 4 | lavrentiya
# Processing Record 27 of Set 4 | pandan
# Processing Record 28 of Set 4 | coihaique
# Processing Record 29 of Set 4 | bathsheba
# Processing Record 30 of Set 4 | leningradskiy
# Processing Record 31 of Set 4 | ribeira grande
# Processing Record 32 of Set 4 | orzhytsya
# Processing Record 33 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 4 | klaksvik
# Processing Record 35 of Set 4 | lasa
# Processing Record 36 of Set 4 | ancud
# Processing Record 37 of Set 4 | sitka
# Processing Record 38 of Set 4 | port augusta
# Processing Record 39 of Set 4 | sao mateus
# Processing Record 40 of Set 4 | amahai
# Processing Record 41 of Set 4 | airai
# Processing Record 42 of Set 4 | playa vicente
# Processing Record 43 of Set 4 | jacareacanga
# Processing Record 44 of Set 4 | sulangan
# Processing Record 45 of Set 4 | chapais
# Processing Record 46 of Set 4 | farah
# Processing Record 47 of Set 4 | ofunato
# Processing Record 48 of Set 4 | shimoda
# Processing Record 49 of Set 4 | kavaratti
# Processing Record 50 of Set 4 | nong khai
# Processing Record 1 of Set 5 | longyearbyen
# Processing Record 2 of Set 5 | simpang
# Processing Record 3 of Set 5 | maniitsoq
# Processing Record 4 of Set 5 | bowen
# Processing Record 5 of Set 5 | quixada
# Processing Record 6 of Set 5 | torbay
# Processing Record 7 of Set 5 | karratha
# Processing Record 8 of Set 5 | hirara
# Processing Record 9 of Set 5 | eyemouth
# Processing Record 10 of Set 5 | liuhe
# Processing Record 11 of Set 5 | arlit
# Processing Record 12 of Set 5 | warmbad
# Processing Record 13 of Set 5 | srednekolymsk
# Processing Record 14 of Set 5 | mount isa
# Processing Record 15 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 16 of Set 5 | laguna
# Processing Record 17 of Set 5 | mokhsogollokh
# Processing Record 18 of Set 5 | petropavl
# Processing Record 19 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 5 | port hardy
# Processing Record 21 of Set 5 | flinders
# Processing Record 22 of Set 5 | ternate
# Processing Record 23 of Set 5 | thinadhoo
# Processing Record 24 of Set 5 | gushi
# Processing Record 25 of Set 5 | rahimatpur
# Processing Record 26 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 5 | yar-sale
# Processing Record 28 of Set 5 | klyuchi
# Processing Record 29 of Set 5 | northam
# Processing Record 30 of Set 5 | sivas
# Processing Record 31 of Set 5 | shache
# Processing Record 32 of Set 5 | bandarbeyla
# Processing Record 33 of Set 5 | nemuro
# Processing Record 34 of Set 5 | gombe
# Processing Record 35 of Set 5 | walvis bay
# Processing Record 36 of Set 5 | alofi
# Processing Record 37 of Set 5 | saint-joseph
# Processing Record 38 of Set 5 | narsaq
# Processing Record 39 of Set 5 | riyadh
# Processing Record 40 of Set 5 | zhanakorgan
# Processing Record 41 of Set 5 | bubaque
# Processing Record 42 of Set 5 | savannah bight
# Processing Record 43 of Set 5 | businga
# Processing Record 44 of Set 5 | ripiceni
# Processing Record 45 of Set 5 | genhe
# Processing Record 46 of Set 5 | varniai
# Processing Record 47 of Set 5 | vila velha
# Processing Record 48 of Set 5 | saskylakh
# Processing Record 49 of Set 5 | el retorno
# Processing Record 50 of Set 5 | bolitoc
# Processing Record 1 of Set 6 | port macquarie
# Processing Record 2 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 6 | ambon
# Processing Record 5 of Set 6 | taoudenni
# Processing Record 6 of Set 6 | warkworth
# Processing Record 7 of Set 6 | dingle
# Processing Record 8 of Set 6 | moose factory
# Processing Record 9 of Set 6 | mayo
# Processing Record 10 of Set 6 | okha
# Processing Record 11 of Set 6 | srivardhan
# Processing Record 12 of Set 6 | loreto
# Processing Record 13 of Set 6 | visby
# Processing Record 14 of Set 6 | bintulu
# Processing Record 15 of Set 6 | cockburn town
# Processing Record 16 of Set 6 | huarmey
# Processing Record 17 of Set 6 | kemijarvi
# Processing Record 18 of Set 6 | champerico
# Processing Record 19 of Set 6 | helong
# Processing Record 20 of Set 6 | kapit
# Processing Record 21 of Set 6 | clyde river
# Processing Record 22 of Set 6 | arraial do cabo
# Processing Record 23 of Set 6 | trelew
# Processing Record 24 of Set 6 | inhambane
# Processing Record 25 of Set 6 | dikson
# Processing Record 26 of Set 6 | were ilu
# Processing Record 27 of Set 6 | letterkenny
# Processing Record 28 of Set 6 | bredasdorp
# Processing Record 29 of Set 6 | katsuura
# Processing Record 30 of Set 6 | bela
# Processing Record 31 of Set 6 | balkhash
# Processing Record 32 of Set 6 | cap-aux-meules
# Processing Record 33 of Set 6 | dongsheng
# Processing Record 34 of Set 6 | bilibino
# Processing Record 35 of Set 6 | carbonia
# Processing Record 36 of Set 6 | bambous virieux
# Processing Record 37 of Set 6 | san carlos de bariloche
# Processing Record 38 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 6 | yumen
# Processing Record 40 of Set 6 | kamyshla
# Processing Record 41 of Set 6 | potchefstroom
# Processing Record 42 of Set 6 | uthal
# Processing Record 43 of Set 6 | mao
# Processing Record 44 of Set 6 | san luis
# Processing Record 45 of Set 6 | sisimiut
# Processing Record 46 of Set 6 | gorontalo
# Processing Record 47 of Set 6 | coahuayana
# Processing Record 48 of Set 6 | hit
# Processing Record 49 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 6 | luorong
# Processing Record 1 of Set 7 | lagoa
# Processing Record 2 of Set 7 | viedma
# Processing Record 3 of Set 7 | cape coast
# Processing Record 4 of Set 7 | denpasar
# Processing Record 5 of Set 7 | talnakh
# Processing Record 6 of Set 7 | dunedin
# Processing Record 7 of Set 7 | douentza
# Processing Record 8 of Set 7 | quatre cocos
# Processing Record 9 of Set 7 | henties bay
# Processing Record 10 of Set 7 | khatanga
# Processing Record 11 of Set 7 | meulaboh
# Processing Record 12 of Set 7 | san borja
# Processing Record 13 of Set 7 | aklavik
# Processing Record 14 of Set 7 | soyo
# Processing Record 15 of Set 7 | te anau
# Processing Record 16 of Set 7 | chernyshevskiy
# Processing Record 17 of Set 7 | karoi
# Processing Record 18 of Set 7 | boyolangu
# Processing Record 19 of Set 7 | mutoko
# Processing Record 20 of Set 7 | kudahuvadhoo
# Processing Record 21 of Set 7 | husavik
# Processing Record 22 of Set 7 | hurghada
# Processing Record 23 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 7 | buchach
# Processing Record 25 of Set 7 | mitzic
# Processing Record 26 of Set 7 | padang
# Processing Record 27 of Set 7 | polson
# Processing Record 28 of Set 7 | north platte
# Processing Record 29 of Set 7 | coos bay
# Processing Record 30 of Set 7 | nyurba
# Processing Record 31 of Set 7 | rocha
# Processing Record 32 of Set 7 | cabedelo
# Processing Record 33 of Set 7 | pacific grove
# Processing Record 34 of Set 7 | saint george
# Processing Record 35 of Set 7 | mehamn
# Processing Record 36 of Set 7 | motygino
# Processing Record 37 of Set 7 | plettenberg bay
# Processing Record 38 of Set 7 | inirida
# Processing Record 39 of Set 7 | tukrah
# Processing Record 40 of Set 7 | saint anthony
# Processing Record 41 of Set 7 | west wendover
# Processing Record 42 of Set 7 | half moon bay
# Processing Record 43 of Set 7 | barcelos
# Processing Record 44 of Set 7 | high level
# Processing Record 45 of Set 7 | cabo san lucas
# Processing Record 46 of Set 7 | berlevag
# Processing Record 47 of Set 7 | kavali
# Processing Record 48 of Set 7 | ketchikan
# Processing Record 49 of Set 7 | nalut
# Processing Record 50 of Set 7 | gamboma
# Processing Record 1 of Set 8 | borogontsy
# Processing Record 2 of Set 8 | deloraine
# Processing Record 3 of Set 8 | yarovoye
# Processing Record 4 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 8 | salekhard
# Processing Record 6 of Set 8 | xining
# Processing Record 7 of Set 8 | luena
# Processing Record 8 of Set 8 | fukue
# Processing Record 9 of Set 8 | kulhudhuffushi
# Processing Record 10 of Set 8 | buala
# Processing Record 11 of Set 8 | namibe
# Processing Record 12 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 8 | geraldton
# Processing Record 14 of Set 8 | cabra
# Processing Record 15 of Set 8 | luderitz
# Processing Record 16 of Set 8 | mahanoro
# Processing Record 17 of Set 8 | arinos
# Processing Record 18 of Set 8 | zyryanka
# Processing Record 19 of Set 8 | filadelfia
# Processing Record 20 of Set 8 | belyy yar
# Processing Record 21 of Set 8 | nhamunda
# Processing Record 22 of Set 8 | mazatlan
# Processing Record 23 of Set 8 | durban
# Processing Record 24 of Set 8 | erenhot
# Processing Record 25 of Set 8 | payson
# Processing Record 26 of Set 8 | komsomolskiy
# Processing Record 27 of Set 8 | constitucion
# Processing Record 28 of Set 8 | fayaoue
# Processing Record 29 of Set 8 | moron
# Processing Record 30 of Set 8 | aquin
# Processing Record 31 of Set 8 | blackwater
# Processing Record 32 of Set 8 | huanuni
# Processing Record 33 of Set 8 | parauna
# Processing Record 34 of Set 8 | barao de melgaco
# Processing Record 35 of Set 8 | mount vernon
# Processing Record 36 of Set 8 | makokou
# Processing Record 37 of Set 8 | lazaro cardenas
# Processing Record 38 of Set 8 | hanstholm
# Processing Record 39 of Set 8 | kango
# Processing Record 40 of Set 8 | salalah
# Processing Record 41 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 8 | okhotsk
# Processing Record 43 of Set 8 | nuevitas
# Processing Record 44 of Set 8 | saurimo
# Processing Record 45 of Set 8 | high rock
# Processing Record 46 of Set 8 | hami
# Processing Record 47 of Set 8 | fredericksburg
# Processing Record 48 of Set 8 | egvekinot
# Processing Record 49 of Set 8 | kattivakkam
# Processing Record 50 of Set 8 | uetendorf
# Processing Record 1 of Set 9 | haapiti
# Processing Record 2 of Set 9 | qandahar
# City not found. Skipping...
# Processing Record 3 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 9 | coquimbo
# Processing Record 5 of Set 9 | labuan
# Processing Record 6 of Set 9 | concarneau
# Processing Record 7 of Set 9 | ilulissat
# Processing Record 8 of Set 9 | porto nacional
# Processing Record 9 of Set 9 | pisco
# Processing Record 10 of Set 9 | chernogorsk
# Processing Record 11 of Set 9 | san cristobal
# Processing Record 12 of Set 9 | port blair
# Processing Record 13 of Set 9 | beringovskiy
# Processing Record 14 of Set 9 | pemba
# Processing Record 15 of Set 9 | taksimo
# Processing Record 16 of Set 9 | itupiranga
# Processing Record 17 of Set 9 | herbertpur
# Processing Record 18 of Set 9 | alta floresta
# Processing Record 19 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 9 | praia da vitoria
# Processing Record 21 of Set 9 | lumberton
# Processing Record 22 of Set 9 | tautira
# Processing Record 23 of Set 9 | horodnytsya
# Processing Record 24 of Set 9 | khurba
# Processing Record 25 of Set 9 | kaitangata
# Processing Record 26 of Set 9 | abu road
# Processing Record 27 of Set 9 | krasnaya gora
# Processing Record 28 of Set 9 | bendigo
# Processing Record 29 of Set 9 | san francisco
# Processing Record 30 of Set 9 | chiria
# Processing Record 31 of Set 9 | jiangyou
# Processing Record 32 of Set 9 | altay
# Processing Record 33 of Set 9 | millinocket
# Processing Record 34 of Set 9 | macamic
# Processing Record 35 of Set 9 | bhatkal
# Processing Record 36 of Set 9 | hobyo
# Processing Record 37 of Set 9 | naze
# Processing Record 38 of Set 9 | santa fe
# Processing Record 39 of Set 9 | qaqortoq
# Processing Record 40 of Set 9 | avera
# Processing Record 41 of Set 9 | lavumisa
# Processing Record 42 of Set 9 | benjamin constant
# Processing Record 43 of Set 9 | sao filipe
# Processing Record 44 of Set 9 | diffa
# Processing Record 45 of Set 9 | inzer
# Processing Record 46 of Set 9 | terra santa
# Processing Record 47 of Set 9 | kondagaon
# Processing Record 48 of Set 9 | antsohihy
# Processing Record 49 of Set 9 | fortuna
# Processing Record 50 of Set 9 | darnah
# Processing Record 1 of Set 10 | tuatapere
# Processing Record 2 of Set 10 | hun
# Processing Record 3 of Set 10 | tshikapa
# Processing Record 4 of Set 10 | senador jose porfirio
# Processing Record 5 of Set 10 | monkey bay
# Processing Record 6 of Set 10 | puerto suarez
# Processing Record 7 of Set 10 | san andres
# Processing Record 8 of Set 10 | faya
# Processing Record 9 of Set 10 | bilma
# Processing Record 10 of Set 10 | roma
# Processing Record 11 of Set 10 | omboue
# Processing Record 12 of Set 10 | san bonifacio
# Processing Record 13 of Set 10 | puerto escondido
# Processing Record 14 of Set 10 | olinda
# Processing Record 15 of Set 10 | tigre
# Processing Record 16 of Set 10 | vondrozo
# Processing Record 17 of Set 10 | roald
# Processing Record 18 of Set 10 | wichita
# Processing Record 19 of Set 10 | rudnyy
# Processing Record 20 of Set 10 | nsoko
# Processing Record 21 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 22 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 24 of Set 10 | payo
# Processing Record 25 of Set 10 | gongzhuling
# Processing Record 26 of Set 10 | poum
# Processing Record 27 of Set 10 | sabla
# Processing Record 28 of Set 10 | jaciara
# Processing Record 29 of Set 10 | skelleftea
# Processing Record 30 of Set 10 | coihueco
# Processing Record 31 of Set 10 | lorengau
# Processing Record 32 of Set 10 | maceio
# Processing Record 33 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 34 of Set 10 | richards bay
# Processing Record 35 of Set 10 | hamilton
# Processing Record 36 of Set 10 | suntar
# Processing Record 37 of Set 10 | waipawa
# Processing Record 38 of Set 10 | kavieng
# Processing Record 39 of Set 10 | taree
# Processing Record 40 of Set 10 | palauig
# Processing Record 41 of Set 10 | vieste
# Processing Record 42 of Set 10 | camopi
# Processing Record 43 of Set 10 | los llanos de aridane
# Processing Record 44 of Set 10 | batagay
# Processing Record 45 of Set 10 | pakxan
# Processing Record 46 of Set 10 | san jeronimo
# Processing Record 47 of Set 10 | marsa matruh
# Processing Record 48 of Set 10 | levanger
# Processing Record 49 of Set 10 | abakaliki
# Processing Record 50 of Set 10 | florence
# Processing Record 1 of Set 11 | montevideo
# Processing Record 2 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 3 of Set 11 | yendi
# Processing Record 4 of Set 11 | zhigansk
# Processing Record 5 of Set 11 | sorong
# Processing Record 6 of Set 11 | lexington
# Processing Record 7 of Set 11 | kerema
# Processing Record 8 of Set 11 | bhatgaon
# Processing Record 9 of Set 11 | pulawy
# Processing Record 10 of Set 11 | aksu
# Processing Record 11 of Set 11 | sechura
# Processing Record 12 of Set 11 | deputatskiy
# Processing Record 13 of Set 11 | maues
# Processing Record 14 of Set 11 | cap malheureux
# Processing Record 15 of Set 11 | muyezerskiy
# Processing Record 16 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 17 of Set 11 | aripuana
# Processing Record 18 of Set 11 | yinchuan
# Processing Record 19 of Set 11 | akcakoca
# Processing Record 20 of Set 11 | basse-terre
# Processing Record 21 of Set 11 | kizukuri
# Processing Record 22 of Set 11 | stornoway
# Processing Record 23 of Set 11 | paamiut
# Processing Record 24 of Set 11 | leshukonskoye
# Processing Record 25 of Set 11 | la romana
# Processing Record 26 of Set 11 | noyabrsk
# Processing Record 27 of Set 11 | mchinji
# Processing Record 28 of Set 11 | la sarre
# Processing Record 29 of Set 11 | sarahan
# Processing Record 30 of Set 11 | newport
# Processing Record 31 of Set 11 | peleduy
# Processing Record 32 of Set 11 | brora
# Processing Record 33 of Set 11 | altamira
# Processing Record 34 of Set 11 | san patricio
# Processing Record 35 of Set 11 | north bend
# Processing Record 36 of Set 11 | darlowo
# Processing Record 37 of Set 11 | shediac
# Processing Record 38 of Set 11 | grand-bourg
# Processing Record 39 of Set 11 | oksovskiy
# Processing Record 40 of Set 11 | ostrovnoy
# Processing Record 41 of Set 11 | nizhniy kuranakh
# Processing Record 42 of Set 11 | kalevala
# Processing Record 43 of Set 11 | linjiang
# Processing Record 44 of Set 11 | whitecourt
# Processing Record 45 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 46 of Set 11 | myanaung
# Processing Record 47 of Set 11 | kisangani
# Processing Record 48 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 49 of Set 11 | camana
# Processing Record 50 of Set 11 | sandwick
# Processing Record 1 of Set 12 | ilsede
# Processing Record 2 of Set 12 | tezu
# Processing Record 3 of Set 12 | pasir gudang
# Processing Record 4 of Set 12 | eureka
# Processing Record 5 of Set 12 | grants pass
# Processing Record 6 of Set 12 | manakara
# Processing Record 7 of Set 12 | concordia
# Processing Record 8 of Set 12 | charleston
# Processing Record 9 of Set 12 | luangwa
# Processing Record 10 of Set 12 | tateyama
# Processing Record 11 of Set 12 | esna
# Processing Record 12 of Set 12 | berdigestyakh
# Processing Record 13 of Set 12 | umm lajj
# Processing Record 14 of Set 12 | ornskoldsvik
# Processing Record 15 of Set 12 | labuhan
# Processing Record 16 of Set 12 | barranca
# Processing Record 17 of Set 12 | el alto
# Processing Record 18 of Set 12 | turayf
# Processing Record 19 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 20 of Set 12 | vardo
# Processing Record 21 of Set 12 | vestmannaeyjar
# Processing Record 22 of Set 12 | riese
# City not found. Skipping...
# Processing Record 23 of Set 12 | port hedland
# Processing Record 24 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 25 of Set 12 | papara
# Processing Record 26 of Set 12 | yamada
# Processing Record 27 of Set 12 | yangjiang
# Processing Record 28 of Set 12 | antofagasta
# Processing Record 29 of Set 12 | sapa
# Processing Record 30 of Set 12 | kharan
# Processing Record 31 of Set 12 | xghajra
# City not found. Skipping...
# Processing Record 32 of Set 12 | aksha
# Processing Record 33 of Set 12 | suzu
# City not found. Skipping...
# Processing Record 34 of Set 12 | ushtobe
# Processing Record 35 of Set 12 | vilyuysk
# Processing Record 36 of Set 12 | iranshahr
# Processing Record 37 of Set 12 | madingou
# Processing Record 38 of Set 12 | zabid
# Processing Record 39 of Set 12 | darhan
# Processing Record 40 of Set 12 | north las vegas
# Processing Record 41 of Set 12 | kampot
# Processing Record 42 of Set 12 | vanavara
# Processing Record 43 of Set 12 | nanortalik
# Processing Record 44 of Set 12 | vestbygda
# City not found. Skipping...
# Processing Record 45 of Set 12 | longyan
# Processing Record 46 of Set 12 | tombouctou
# Processing Record 47 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 48 of Set 12 | sioux lookout
# Processing Record 49 of Set 12 | turan
# Processing Record 50 of Set 12 | veraval
# Processing Record 1 of Set 13 | da nang
# Processing Record 2 of Set 13 | lengshuitan
# Processing Record 3 of Set 13 | quang ngai
# Processing Record 4 of Set 13 | buenos aires
# Processing Record 5 of Set 13 | guane
# Processing Record 6 of Set 13 | nhulunbuy
# Processing Record 7 of Set 13 | ucluelet
# Processing Record 8 of Set 13 | jilin
# Processing Record 9 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 10 of Set 13 | kuyanovo
# Processing Record 11 of Set 13 | thabazimbi
# Processing Record 12 of Set 13 | adet
# Processing Record 13 of Set 13 | svetlyy
# Processing Record 14 of Set 13 | buchanan
# Processing Record 15 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 16 of Set 13 | rio claro
# Processing Record 17 of Set 13 | yarim
# Processing Record 18 of Set 13 | bembereke
# Processing Record 19 of Set 13 | minas de barroteran
# Processing Record 20 of Set 13 | mayor pablo lagerenza
# Processing Record 21 of Set 13 | westport
# Processing Record 22 of Set 13 | waingapu
# Processing Record 23 of Set 13 | oktyabrskiy
# Processing Record 24 of Set 13 | gorom-gorom
# Processing Record 25 of Set 13 | san ramon
# Processing Record 26 of Set 13 | greenfield
# Processing Record 27 of Set 13 | ponezhukay
# Processing Record 28 of Set 13 | sudbury
# Processing Record 29 of Set 13 | sawakin
# Processing Record 30 of Set 13 | kilindoni
# Processing Record 31 of Set 13 | barra patuca
# Processing Record 32 of Set 13 | ambanja
# Processing Record 33 of Set 13 | ballina
# Processing Record 34 of Set 13 | marienburg
# Processing Record 35 of Set 13 | ciudad bolivar
# Processing Record 36 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 37 of Set 13 | togur
# Processing Record 38 of Set 13 | jaguey grande
# Processing Record 39 of Set 13 | tual
# Processing Record 40 of Set 13 | huron
# Processing Record 41 of Set 13 | raudeberg
# Processing Record 42 of Set 13 | urumqi
# Processing Record 43 of Set 13 | burica
# City not found. Skipping...
# Processing Record 44 of Set 13 | drovyanaya
# Processing Record 45 of Set 13 | harper
# Processing Record 46 of Set 13 | marzuq
# Processing Record 47 of Set 13 | awjilah
# Processing Record 48 of Set 13 | bereda
# Processing Record 49 of Set 13 | dhidhdhoo
# Processing Record 50 of Set 13 | kushima
# Processing Record 1 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 14 | palmer
# Processing Record 3 of Set 14 | gizo
# Processing Record 4 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 5 of Set 14 | banda aceh
# Processing Record 6 of Set 14 | nova floresta
# Processing Record 7 of Set 14 | inta
# Processing Record 8 of Set 14 | pronsk
# Processing Record 9 of Set 14 | mehriz
# Processing Record 10 of Set 14 | mattru
# Processing Record 11 of Set 14 | gilazi
# City not found. Skipping...
# Processing Record 12 of Set 14 | gali
# Processing Record 13 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 14 | taltal
# Processing Record 15 of Set 14 | charters towers
# Processing Record 16 of Set 14 | bobcaygeon
# Processing Record 17 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 14 | magadan
# Processing Record 19 of Set 14 | el pino
# Processing Record 20 of Set 14 | dawei
# Processing Record 21 of Set 14 | ploemeur
# Processing Record 22 of Set 14 | nanton
# Processing Record 23 of Set 14 | fort nelson
# Processing Record 24 of Set 14 | gummidipundi
# Processing Record 25 of Set 14 | hede
# Processing Record 26 of Set 14 | piacabucu
# Processing Record 27 of Set 14 | karatau
# Processing Record 28 of Set 14 | kamenka
# Processing Record 29 of Set 14 | hovd
# Processing Record 30 of Set 14 | palmeirais
# Processing Record 31 of Set 14 | mitu
# Processing Record 32 of Set 14 | tokur
# Processing Record 33 of Set 14 | zaraza
# Processing Record 34 of Set 14 | sokoto
# Processing Record 35 of Set 14 | haifa
# Processing Record 36 of Set 14 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 37 of Set 14 | chittaurgarh
# Processing Record 38 of Set 14 | bom jesus
# Processing Record 39 of Set 14 | christchurch
# Processing Record 40 of Set 14 | eagle pass
# Processing Record 41 of Set 14 | visnes
# Processing Record 42 of Set 14 | sahuaripa
# Processing Record 43 of Set 14 | tanout
# Processing Record 44 of Set 14 | kalmar
# Processing Record 45 of Set 14 | caborca
# Processing Record 46 of Set 14 | chalchihuites
# Processing Record 47 of Set 14 | comodoro rivadavia
# Processing Record 48 of Set 14 | khandyga
# Processing Record 49 of Set 14 | mogadishu
# Processing Record 50 of Set 14 | ossora
# Processing Record 1 of Set 15 | malangali
# Processing Record 2 of Set 15 | kytlym
# City not found. Skipping...
# Processing Record 3 of Set 15 | great bend
# Processing Record 4 of Set 15 | whitehorse
# Processing Record 5 of Set 15 | umm ruwabah
# City not found. Skipping...
# Processing Record 6 of Set 15 | shingu
# Processing Record 7 of Set 15 | ostersund
# Processing Record 8 of Set 15 | kirakira
# Processing Record 9 of Set 15 | shwebo
# Processing Record 10 of Set 15 | corowa
# Processing Record 11 of Set 15 | dalvik
# Processing Record 12 of Set 15 | jacksonville
# Processing Record 13 of Set 15 | ferkessedougou
# Processing Record 14 of Set 15 | price
# Processing Record 15 of Set 15 | muscat
# Processing Record 16 of Set 15 | tura
# Processing Record 17 of Set 15 | loandjili
# Processing Record 18 of Set 15 | gao
# Processing Record 19 of Set 15 | jutai
# Processing Record 20 of Set 15 | maxixe
# Processing Record 21 of Set 15 | luanda
# Processing Record 22 of Set 15 | annau
# Processing Record 23 of Set 15 | horta
# Processing Record 24 of Set 15 | san jose
# Processing Record 25 of Set 15 | savonlinna
# Processing Record 26 of Set 15 | zabaykalsk
# Processing Record 27 of Set 15 | drezdenko
# Processing Record 28 of Set 15 | qurayyat
# Processing Record 29 of Set 15 | sao raimundo das mangabeiras
# Processing Record 30 of Set 15 | mabama
# Processing Record 31 of Set 15 | grindavik
# Processing Record 32 of Set 15 | broken hill
# Processing Record 33 of Set 15 | shaoyang
# Processing Record 34 of Set 15 | maningrida
# Processing Record 35 of Set 15 | antalaha
# Processing Record 36 of Set 15 | el vigia
# Processing Record 37 of Set 15 | alekseyevsk
# Processing Record 38 of Set 15 | paragominas
# Processing Record 39 of Set 15 | villazon
# Processing Record 40 of Set 15 | liverpool
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Madison Heights  42.49  -83.11     64.40        48           1       10.29
# 1          Ahipara -35.17  173.17     65.43        94          96        8.41
# 2     Norman Wells  65.28 -126.83    -16.60        75          40        2.24
# 3        Sinnamary   5.38  -52.95     79.32        86          99        9.10
# 4        Caravelas -17.71  -39.25     71.29        94         100        4.74
# 5     Punta Arenas -53.15  -70.92     46.40        87          90       10.29
# 6         Camacari -12.70  -38.32     77.00        94          75       11.41
# 7        Ulladulla -35.35  150.47     53.60        93          75       10.29
# 8         Tasiilaq  65.61  -37.64     30.20        50          87       14.99
# 9            Vaini -21.20 -175.20     80.60        74          40       13.87
#
#   Country   Current Description
# 0      US             clear sky
# 1      NZ       overcast clouds
# 2      CA      scattered clouds
# 3      GF         moderate rain
# 4      BR  heavy intensity rain
# 5      CL            light rain
# 6      BR           shower rain
# 7      AU            light rain
# 8      GL       overcast clouds
# 9      TO      scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Madison Heights      US  42.49  -83.11     64.40        48           1
# 1          Ahipara      NZ -35.17  173.17     65.43        94          96
# 2     Norman Wells      CA  65.28 -126.83    -16.60        75          40
# 3        Sinnamary      GF   5.38  -52.95     79.32        86          99
# 4        Caravelas      BR -17.71  -39.25     71.29        94         100
# 5     Punta Arenas      CL -53.15  -70.92     46.40        87          90
# 6         Camacari      BR -12.70  -38.32     77.00        94          75
# 7        Ulladulla      AU -35.35  150.47     53.60        93          75
# 8         Tasiilaq      GL  65.61  -37.64     30.20        50          87
# 9            Vaini      TO -21.20 -175.20     80.60        74          40
#
#    Wind Speed   Current Description
# 0       10.29             clear sky
# 1        8.41       overcast clouds
# 2        2.24      scattered clouds
# 3        9.10         moderate rain
# 4        4.74  heavy intensity rain
# 5       10.29            light rain
# 6       11.41           shower rain
# 7       10.29            light rain
# 8       14.99       overcast clouds
# 9       13.87      scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
